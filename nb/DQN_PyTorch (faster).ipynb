# %% [markdown]
# ## PyTorch DQN (faster)

# %%
import gym
import matplotlib.pyplot as plt
import torch
import numpy as np

from dqn_agent import DQNAgent
from agent_trainer import Trainer
from memory_buffer import MemoryBuffer
import random

results = {}
# Out:
# WARNING:root:This caffe2 python run does not have GPU support. Will run in CPU only mode.

# %%
env = gym.make('CartPole-v0')

# %%
env.reset()
# Out:
# array([-0.01705638, -0.04632958,  0.01395975,  0.03547057])

# %%
env = gym.make('CartPole-v0')
RANDOM_SEED = 0

torch.manual_seed(RANDOM_SEED)
env.seed(RANDOM_SEED)
env.action_space.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

dqn_agent = DQNAgent(learning_rate=0.00025, 
                     discount_rate=0.99,
                     num_inputs=4,
                     num_neurons=64,
                     num_outputs=2,
                     duelling=False,
                     loss_type='huber'
                    )

trainer = Trainer(
    env=env, 
    agent=dqn_agent, 
    memory_buffer=MemoryBuffer(buffer_length=50000), 
    start_epsilon=1, 
    timestep_to_start_learning=1000,
    batch_size=32,
    target_update_steps=1000,
    epsilon_decay_rate=0.99
)


trainer.run(num_episodes=1000)

results[RANDOM_SEED] = trainer.episode_lengths.copy()
# Out:
# Trainer initialised.
# Target network updated.
# Ep 0; 52 steps. 100 ep ravg: 51.0. Eps 1.00. Loss: inf|inf|inf
# Ep 10; 22 steps. 100 ep ravg: 25.0. Eps 0.90. Loss: inf|inf|inf
# Ep 20; 11 steps. 100 ep ravg: 26.0. Eps 0.82. Loss: inf|inf|inf
# Ep 30; 22 steps. 100 ep ravg: 23.0. Eps 0.74. Loss: inf|inf|inf
# Ep 40; 12 steps. 100 ep ravg: 22.0. Eps 0.67. Loss: inf|inf|inf
# Target network updated.
# Ep 50; 12 steps. 100 ep ravg: 20.0. Eps 0.61. Loss: 0.28|0.42|0.57
# Ep 60; 18 steps. 100 ep ravg: 19.0. Eps 0.55. Loss: 0.10|0.16|0.24
# Ep 70; 15 steps. 100 ep ravg: 18.0. Eps 0.49. Loss: 0.03|0.07|0.13
# Ep 80; 13 steps. 100 ep ravg: 17.0. Eps 0.45. Loss: 0.01|0.04|0.07
# Ep 90; 14 steps. 100 ep ravg: 17.0. Eps 0.40. Loss: 0.01|0.02|0.08
# Ep 100; 9 steps. 100 ep ravg: 16.0. Eps 0.37. Loss: 0.00|0.01|0.05
# Ep 110; 10 steps. 100 ep ravg: 14.0. Eps 0.33. Loss: 0.00|0.01|0.02
# Ep 120; 10 steps. 100 ep ravg: 13.0. Eps 0.30. Loss: 0.00|0.01|0.02
# Target network updated.
# Ep 130; 8 steps. 100 ep ravg: 12.0. Eps 0.27. Loss: 0.00|0.22|0.52
# Ep 140; 10 steps. 100 ep ravg: 11.0. Eps 0.24. Loss: 0.01|0.07|0.18
# Ep 150; 9 steps. 100 ep ravg: 10.0. Eps 0.22. Loss: 0.01|0.06|0.14
# Ep 160; 10 steps. 100 ep ravg: 10.0. Eps 0.20. Loss: 0.01|0.05|0.14
# Ep 170; 10 steps. 100 ep ravg: 10.0. Eps 0.18. Loss: 0.00|0.05|0.12
# Ep 180; 10 steps. 100 ep ravg: 10.0. Eps 0.16. Loss: 0.00|0.05|0.13
# Ep 190; 9 steps. 100 ep ravg: 9.0. Eps 0.15. Loss: 0.01|0.05|0.11
# Ep 200; 11 steps. 100 ep ravg: 9.0. Eps 0.13. Loss: 0.01|0.05|0.12
# Ep 210; 9 steps. 100 ep ravg: 9.0. Eps 0.12. Loss: 0.01|0.05|0.12
# Target network updated.
# Ep 220; 11 steps. 100 ep ravg: 9.0. Eps 0.11. Loss: 0.01|0.11|0.50
# Ep 230; 10 steps. 100 ep ravg: 9.0. Eps 0.10. Loss: 0.01|0.15|0.39
# Ep 240; 10 steps. 100 ep ravg: 9.0. Eps 0.09. Loss: 0.01|0.09|0.29
# Ep 250; 10 steps. 100 ep ravg: 9.0. Eps 0.08. Loss: 0.01|0.09|0.29
# Ep 260; 10 steps. 100 ep ravg: 9.0. Eps 0.07. Loss: 0.01|0.10|0.31
# Ep 270; 10 steps. 100 ep ravg: 9.0. Eps 0.07. Loss: 0.01|0.09|0.23
# Ep 280; 9 steps. 100 ep ravg: 9.0. Eps 0.06. Loss: 0.01|0.09|0.25
# Ep 290; 10 steps. 100 ep ravg: 9.0. Eps 0.05. Loss: 0.01|0.08|0.21
# Ep 300; 10 steps. 100 ep ravg: 9.0. Eps 0.05. Loss: 0.00|0.09|0.22
# Ep 310; 9 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.01|0.09|0.18
# Target network updated.
# Ep 320; 10 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.02|0.14|0.47
# Ep 330; 13 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.01|0.14|0.44
# Ep 340; 15 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.01|0.11|0.35
# Ep 350; 17 steps. 100 ep ravg: 11.0. Eps 0.03. Loss: 0.01|0.10|0.29
# Ep 360; 20 steps. 100 ep ravg: 12.0. Eps 0.03. Loss: 0.02|0.12|0.40
# Target network updated.
# Ep 370; 25 steps. 100 ep ravg: 14.0. Eps 0.02. Loss: 0.01|0.17|0.61
# Ep 380; 114 steps. 100 ep ravg: 21.0. Eps 0.02. Loss: 0.01|0.11|0.31
# Target network updated.
# Ep 390; 10 steps. 100 ep ravg: 22.0. Eps 0.02. Loss: 0.00|0.20|0.57
# Target network updated.
# Ep 400; 118 steps. 100 ep ravg: 31.0. Eps 0.02. Loss: 0.00|0.19|0.70
# Target network updated.
# Ep 410; 87 steps. 100 ep ravg: 40.0. Eps 0.02. Loss: 0.00|0.21|0.70
# Target network updated.
# Ep 420; 79 steps. 100 ep ravg: 50.0. Eps 0.01. Loss: 0.00|0.19|0.78
# Target network updated.
# Ep 430; 135 steps. 100 ep ravg: 60.0. Eps 0.01. Loss: 0.00|0.20|0.77
# Target network updated.
# Ep 440; 148 steps. 100 ep ravg: 72.0. Eps 0.01. Loss: 0.00|0.19|0.75
# Target network updated.
# Ep 450; 89 steps. 100 ep ravg: 81.0. Eps 0.01. Loss: 0.00|0.20|1.13
# Target network updated.
# Target network updated.
# Ep 460; 178 steps. 100 ep ravg: 93.0. Eps 0.01. Loss: 0.00|0.19|0.74
# Target network updated.
# Ep 470; 200 steps. 100 ep ravg: 103.0. Eps 0.01. Loss: 0.00|0.25|1.14
# Target network updated.
# Ep 480; 111 steps. 100 ep ravg: 107.0. Eps 0.01. Loss: 0.00|0.20|1.43
# Target network updated.
# Ep 490; 84 steps. 100 ep ravg: 116.0. Eps 0.01. Loss: 0.00|0.23|1.33
# Target network updated.
# Ep 500; 92 steps. 100 ep ravg: 116.0. Eps 0.01. Loss: 0.00|0.31|1.46
# Target network updated.
# Target network updated.
# Ep 510; 109 steps. 100 ep ravg: 118.0. Eps 0.01. Loss: 0.00|0.28|1.25
# Ep 520; 110 steps. 100 ep ravg: 117.0. Eps 0.01. Loss: 0.00|0.29|1.99
# Target network updated.
# Target network updated.
# Ep 530; 117 steps. 100 ep ravg: 116.0. Eps 0.01. Loss: 0.00|0.34|1.74
# Target network updated.
# Ep 540; 149 steps. 100 ep ravg: 119.0. Eps 0.01. Loss: 0.00|0.42|1.55
# Target network updated.
# Target network updated.
# Ep 550; 134 steps. 100 ep ravg: 123.0. Eps 0.01. Loss: 0.00|0.27|1.80
# Target network updated.
# Ep 560; 150 steps. 100 ep ravg: 126.0. Eps 0.01. Loss: 0.00|0.27|1.50
# Target network updated.
# Target network updated.
# Ep 570; 200 steps. 100 ep ravg: 131.0. Eps 0.01. Loss: 0.00|0.28|1.51
# Target network updated.
# Target network updated.
# Ep 580; 172 steps. 100 ep ravg: 133.0. Eps 0.01. Loss: 0.00|0.30|1.58
# Target network updated.
# Target network updated.
# Ep 590; 200 steps. 100 ep ravg: 142.0. Eps 0.01. Loss: 0.00|0.33|1.74
# Target network updated.
# Target network updated.
# Ep 600; 200 steps. 100 ep ravg: 152.0. Eps 0.01. Loss: 0.00|0.36|1.68
# Target network updated.
# Target network updated.
# Ep 610; 200 steps. 100 ep ravg: 159.0. Eps 0.01. Loss: 0.00|0.42|1.50
# Target network updated.
# Ep 620; 200 steps. 100 ep ravg: 167.0. Eps 0.01. Loss: 0.00|0.33|2.06
# Target network updated.
# Target network updated.
# Ep 630; 200 steps. 100 ep ravg: 173.0. Eps 0.01. Loss: 0.00|0.40|2.32
# Target network updated.
# Ep 640; 150 steps. 100 ep ravg: 171.0. Eps 0.01. Loss: 0.00|0.43|1.78
# Target network updated.
# Target network updated.
# Ep 650; 200 steps. 100 ep ravg: 172.0. Eps 0.01. Loss: 0.00|0.43|1.55
# Target network updated.
# Target network updated.
# Ep 660; 123 steps. 100 ep ravg: 170.0. Eps 0.01. Loss: 0.00|0.35|2.61
# Target network updated.
# Ep 670; 112 steps. 100 ep ravg: 165.0. Eps 0.01. Loss: 0.00|0.43|1.99
# Target network updated.
# Ep 680; 147 steps. 100 ep ravg: 165.0. Eps 0.01. Loss: 0.00|0.39|2.64
# Target network updated.
# Target network updated.
# Ep 690; 127 steps. 100 ep ravg: 159.0. Eps 0.01. Loss: 0.00|0.38|2.73
# Target network updated.
# Ep 700; 115 steps. 100 ep ravg: 151.0. Eps 0.01. Loss: 0.00|0.39|3.21
# Target network updated.
# Ep 710; 123 steps. 100 ep ravg: 145.0. Eps 0.01. Loss: 0.00|0.47|2.68
# Target network updated.
# Ep 720; 122 steps. 100 ep ravg: 140.0. Eps 0.01. Loss: 0.00|0.36|2.36
# Target network updated.
# Target network updated.
# Ep 730; 119 steps. 100 ep ravg: 136.0. Eps 0.01. Loss: 0.00|0.36|2.24
# Target network updated.
# Ep 740; 169 steps. 100 ep ravg: 137.0. Eps 0.01. Loss: 0.00|0.21|1.30
# Target network updated.
# Target network updated.
# Ep 750; 200 steps. 100 ep ravg: 137.0. Eps 0.01. Loss: 0.00|0.35|3.16
# Target network updated.
# Target network updated.
# Ep 760; 200 steps. 100 ep ravg: 140.0. Eps 0.01. Loss: 0.00|0.23|2.53
# Target network updated.
# Target network updated.
# Ep 770; 200 steps. 100 ep ravg: 145.0. Eps 0.01. Loss: 0.00|0.29|1.42
# Target network updated.
# Ep 780; 200 steps. 100 ep ravg: 149.0. Eps 0.01. Loss: 0.00|0.21|2.07
# Target network updated.
# Target network updated.
# Ep 790; 200 steps. 100 ep ravg: 153.0. Eps 0.01. Loss: 0.00|0.20|2.29
# Target network updated.
# Target network updated.
# Ep 800; 146 steps. 100 ep ravg: 157.0. Eps 0.01. Loss: 0.00|0.16|1.45
# Target network updated.
# Target network updated.
# Ep 810; 200 steps. 100 ep ravg: 163.0. Eps 0.01. Loss: 0.00|0.21|2.76
# Target network updated.
# Ep 820; 200 steps. 100 ep ravg: 166.0. Eps 0.01. Loss: 0.00|0.29|2.71
# Target network updated.
# Target network updated.
# Ep 830; 200 steps. 100 ep ravg: 170.0. Eps 0.01. Loss: 0.00|0.25|2.45
# Target network updated.
# Ep 840; 178 steps. 100 ep ravg: 171.0. Eps 0.01. Loss: 0.00|0.27|1.59
# Target network updated.
# Target network updated.
# Ep 850; 130 steps. 100 ep ravg: 168.0. Eps 0.01. Loss: 0.00|0.32|2.86
# Target network updated.
# Ep 860; 134 steps. 100 ep ravg: 165.0. Eps 0.01. Loss: 0.00|0.25|2.51
# Target network updated.
# Target network updated.
# Ep 870; 142 steps. 100 ep ravg: 163.0. Eps 0.01. Loss: 0.00|0.13|1.66
# Target network updated.
# Ep 880; 137 steps. 100 ep ravg: 158.0. Eps 0.01. Loss: 0.00|0.24|2.49
# Target network updated.
# Target network updated.
# Ep 890; 200 steps. 100 ep ravg: 157.0. Eps 0.01. Loss: 0.00|0.23|2.83
# Target network updated.
# Target network updated.
# Ep 900; 140 steps. 100 ep ravg: 156.0. Eps 0.01. Loss: 0.00|0.19|2.54
# Target network updated.
# Ep 910; 190 steps. 100 ep ravg: 154.0. Eps 0.01. Loss: 0.00|0.19|2.91
# Target network updated.
# Target network updated.
# Ep 920; 196 steps. 100 ep ravg: 156.0. Eps 0.01. Loss: 0.00|0.26|2.81
# Target network updated.
# Target network updated.
# Ep 930; 146 steps. 100 ep ravg: 159.0. Eps 0.01. Loss: 0.00|0.28|2.95
# Target network updated.
# Target network updated.
# Ep 940; 200 steps. 100 ep ravg: 162.0. Eps 0.01. Loss: 0.00|0.35|4.16
# Target network updated.
# Target network updated.
# Ep 950; 200 steps. 100 ep ravg: 167.0. Eps 0.01. Loss: 0.00|0.21|3.49
# Target network updated.
# Target network updated.
# Ep 960; 200 steps. 100 ep ravg: 172.0. Eps 0.01. Loss: 0.00|0.31|2.82
# Target network updated.
# Target network updated.
# Ep 970; 200 steps. 100 ep ravg: 177.0. Eps 0.01. Loss: 0.00|0.23|2.24
# Target network updated.
# Target network updated.
# Ep 980; 200 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.29|3.58
# Target network updated.
# Target network updated.
# Ep 990; 200 steps. 100 ep ravg: 186.0. Eps 0.01. Loss: 0.00|0.25|1.94
# Target network updated.
# Target network updated.

# %%
env = gym.make('CartPole-v0')
RANDOM_SEED = 1

torch.manual_seed(RANDOM_SEED)
env.seed(RANDOM_SEED)
env.action_space.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

dqn_agent = DQNAgent(learning_rate=0.00025, 
                     discount_rate=0.99,
                     num_inputs=4,
                     num_neurons=64,
                     num_outputs=2,
                     duelling=False,
                     loss_type='huber'
                    )

trainer = Trainer(
    env=env, 
    agent=dqn_agent, 
    memory_buffer=MemoryBuffer(buffer_length=50000), 
    start_epsilon=1, 
    timestep_to_start_learning=1000,
    batch_size=32,
    target_update_steps=1000,
    epsilon_decay_rate=0.99
)


trainer.run(num_episodes=1000)

results[RANDOM_SEED] = trainer.episode_lengths.copy()
# Out:
# Trainer initialised.
# Target network updated.
# Ep 0; 15 steps. 100 ep ravg: 14.0. Eps 1.00. Loss: inf|inf|inf
# Ep 10; 26 steps. 100 ep ravg: 27.0. Eps 0.90. Loss: inf|inf|inf
# Ep 20; 23 steps. 100 ep ravg: 28.0. Eps 0.82. Loss: inf|inf|inf
# Ep 30; 55 steps. 100 ep ravg: 26.0. Eps 0.74. Loss: inf|inf|inf
# Target network updated.
# Ep 40; 12 steps. 100 ep ravg: 26.0. Eps 0.67. Loss: 0.24|0.37|0.51
# Ep 50; 44 steps. 100 ep ravg: 28.0. Eps 0.61. Loss: 0.01|0.02|0.03
# Ep 60; 39 steps. 100 ep ravg: 28.0. Eps 0.55. Loss: 0.00|0.00|0.01
# Target network updated.
# Ep 70; 68 steps. 100 ep ravg: 30.0. Eps 0.49. Loss: 0.00|0.02|0.07
# Ep 80; 22 steps. 100 ep ravg: 30.0. Eps 0.45. Loss: 0.00|0.02|0.05
# Ep 90; 36 steps. 100 ep ravg: 28.0. Eps 0.40. Loss: 0.00|0.02|0.07
# Ep 100; 10 steps. 100 ep ravg: 27.0. Eps 0.37. Loss: 0.00|0.02|0.07
# Ep 110; 9 steps. 100 ep ravg: 25.0. Eps 0.33. Loss: 0.00|0.02|0.06
# Target network updated.
# Ep 120; 59 steps. 100 ep ravg: 28.0. Eps 0.30. Loss: 0.00|0.05|0.15
# Target network updated.
# Ep 130; 107 steps. 100 ep ravg: 32.0. Eps 0.27. Loss: 0.00|0.07|0.27
# Ep 140; 49 steps. 100 ep ravg: 35.0. Eps 0.24. Loss: 0.00|0.05|0.23
# Target network updated.
# Ep 150; 37 steps. 100 ep ravg: 36.0. Eps 0.22. Loss: 0.00|0.09|0.38
# Ep 160; 47 steps. 100 ep ravg: 39.0. Eps 0.20. Loss: 0.00|0.07|0.31
# Target network updated.
# Ep 170; 48 steps. 100 ep ravg: 43.0. Eps 0.18. Loss: 0.00|0.10|0.58
# Target network updated.
# Ep 180; 97 steps. 100 ep ravg: 49.0. Eps 0.16. Loss: 0.00|0.12|0.44
# Target network updated.
# Ep 190; 98 steps. 100 ep ravg: 57.0. Eps 0.15. Loss: 0.00|0.12|0.53
# Target network updated.
# Ep 200; 94 steps. 100 ep ravg: 67.0. Eps 0.13. Loss: 0.00|0.14|0.85
# Target network updated.
# Target network updated.
# Ep 210; 140 steps. 100 ep ravg: 79.0. Eps 0.12. Loss: 0.00|0.18|0.94
# Target network updated.
# Ep 220; 199 steps. 100 ep ravg: 88.0. Eps 0.11. Loss: 0.00|0.16|1.13
# Target network updated.
# Ep 230; 142 steps. 100 ep ravg: 95.0. Eps 0.10. Loss: 0.00|0.18|0.65
# Target network updated.
# Target network updated.
# Ep 240; 200 steps. 100 ep ravg: 109.0. Eps 0.09. Loss: 0.00|0.19|1.14
# Target network updated.
# Target network updated.
# Ep 250; 180 steps. 100 ep ravg: 123.0. Eps 0.08. Loss: 0.00|0.18|0.84
# Target network updated.
# Target network updated.
# Ep 260; 200 steps. 100 ep ravg: 134.0. Eps 0.07. Loss: 0.00|0.22|1.38
# Target network updated.
# Target network updated.
# Ep 270; 200 steps. 100 ep ravg: 143.0. Eps 0.07. Loss: 0.00|0.20|1.50
# Target network updated.
# Target network updated.
# Ep 280; 197 steps. 100 ep ravg: 154.0. Eps 0.06. Loss: 0.00|0.24|1.75
# Target network updated.
# Ep 290; 174 steps. 100 ep ravg: 163.0. Eps 0.05. Loss: 0.00|0.21|1.77
# Target network updated.
# Target network updated.
# Ep 300; 192 steps. 100 ep ravg: 169.0. Eps 0.05. Loss: 0.00|0.30|1.78
# Target network updated.
# Target network updated.
# Ep 310; 200 steps. 100 ep ravg: 174.0. Eps 0.04. Loss: 0.00|0.22|1.35
# Target network updated.
# Target network updated.
# Ep 320; 187 steps. 100 ep ravg: 179.0. Eps 0.04. Loss: 0.00|0.24|1.46
# Target network updated.
# Target network updated.
# Ep 330; 200 steps. 100 ep ravg: 184.0. Eps 0.04. Loss: 0.00|0.23|1.44
# Target network updated.
# Target network updated.
# Ep 340; 181 steps. 100 ep ravg: 184.0. Eps 0.03. Loss: 0.00|0.26|1.69
# Target network updated.
# Target network updated.
# Ep 350; 187 steps. 100 ep ravg: 184.0. Eps 0.03. Loss: 0.00|0.26|1.80
# Target network updated.
# Target network updated.
# Ep 360; 178 steps. 100 ep ravg: 185.0. Eps 0.03. Loss: 0.00|0.20|1.00
# Target network updated.
# Ep 370; 174 steps. 100 ep ravg: 187.0. Eps 0.02. Loss: 0.00|0.30|1.85
# Target network updated.
# Target network updated.
# Ep 380; 196 steps. 100 ep ravg: 185.0. Eps 0.02. Loss: 0.00|0.34|3.71
# Target network updated.
# Target network updated.
# Ep 390; 200 steps. 100 ep ravg: 186.0. Eps 0.02. Loss: 0.00|0.31|1.97
# Target network updated.
# Target network updated.
# Ep 400; 178 steps. 100 ep ravg: 187.0. Eps 0.02. Loss: 0.00|0.27|3.04
# Target network updated.
# Target network updated.
# Ep 410; 174 steps. 100 ep ravg: 186.0. Eps 0.02. Loss: 0.00|0.33|2.90
# Target network updated.
# Ep 420; 147 steps. 100 ep ravg: 182.0. Eps 0.01. Loss: 0.00|0.24|2.06
# Target network updated.
# Target network updated.
# Ep 430; 189 steps. 100 ep ravg: 182.0. Eps 0.01. Loss: 0.00|0.23|2.25
# Target network updated.
# Target network updated.
# Ep 440; 200 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.24|2.42
# Target network updated.
# Target network updated.
# Ep 450; 192 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.23|2.31
# Target network updated.
# Target network updated.
# Ep 460; 181 steps. 100 ep ravg: 182.0. Eps 0.01. Loss: 0.00|0.23|2.29
# Target network updated.
# Target network updated.
# Ep 470; 179 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.22|1.33
# Target network updated.
# Target network updated.
# Ep 480; 174 steps. 100 ep ravg: 182.0. Eps 0.01. Loss: 0.00|0.17|2.36
# Target network updated.
# Target network updated.
# Ep 490; 200 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.14|2.43
# Target network updated.
# Target network updated.
# Ep 500; 184 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.28|2.47
# Target network updated.
# Ep 510; 180 steps. 100 ep ravg: 185.0. Eps 0.01. Loss: 0.00|0.21|1.39
# Target network updated.
# Target network updated.
# Ep 520; 198 steps. 100 ep ravg: 188.0. Eps 0.01. Loss: 0.00|0.22|2.57
# Target network updated.
# Target network updated.
# Ep 530; 189 steps. 100 ep ravg: 186.0. Eps 0.01. Loss: 0.00|0.19|1.53
# Target network updated.
# Target network updated.
# Ep 540; 165 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.25|4.15
# Target network updated.
# Ep 550; 167 steps. 100 ep ravg: 181.0. Eps 0.01. Loss: 0.00|0.20|2.67
# Target network updated.
# Target network updated.
# Ep 560; 200 steps. 100 ep ravg: 183.0. Eps 0.01. Loss: 0.00|0.24|1.61
# Target network updated.
# Target network updated.
# Ep 570; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.24|1.57
# Target network updated.
# Target network updated.
# Ep 580; 200 steps. 100 ep ravg: 186.0. Eps 0.01. Loss: 0.00|0.17|1.54
# Target network updated.
# Target network updated.
# Ep 590; 200 steps. 100 ep ravg: 186.0. Eps 0.01. Loss: 0.00|0.27|3.04
# Target network updated.
# Target network updated.
# Ep 600; 200 steps. 100 ep ravg: 187.0. Eps 0.01. Loss: 0.00|0.23|2.99
# Target network updated.
# Target network updated.
# Ep 610; 200 steps. 100 ep ravg: 187.0. Eps 0.01. Loss: 0.00|0.19|1.59
# Target network updated.
# Target network updated.
# Ep 620; 200 steps. 100 ep ravg: 187.0. Eps 0.01. Loss: 0.00|0.18|3.03
# Target network updated.
# Target network updated.
# Ep 630; 200 steps. 100 ep ravg: 190.0. Eps 0.01. Loss: 0.00|0.31|4.38
# Target network updated.
# Target network updated.
# Ep 640; 200 steps. 100 ep ravg: 193.0. Eps 0.01. Loss: 0.00|0.22|1.77
# Target network updated.
# Target network updated.
# Ep 650; 200 steps. 100 ep ravg: 196.0. Eps 0.01. Loss: 0.00|0.25|3.15
# Target network updated.
# Target network updated.
# Ep 660; 200 steps. 100 ep ravg: 196.0. Eps 0.01. Loss: 0.00|0.25|3.23
# Target network updated.
# Target network updated.
# Ep 670; 200 steps. 100 ep ravg: 196.0. Eps 0.01. Loss: 0.00|0.23|2.35
# Target network updated.
# Target network updated.
# Ep 680; 200 steps. 100 ep ravg: 196.0. Eps 0.01. Loss: 0.00|0.13|1.73
# Target network updated.
# Target network updated.
# Ep 690; 200 steps. 100 ep ravg: 196.0. Eps 0.01. Loss: 0.00|0.37|3.44
# Target network updated.
# Target network updated.
# Ep 700; 200 steps. 100 ep ravg: 197.0. Eps 0.01. Loss: 0.00|0.24|3.33
# Target network updated.
# Target network updated.
# Ep 710; 200 steps. 100 ep ravg: 197.0. Eps 0.01. Loss: 0.00|0.44|5.44
# Target network updated.
# Target network updated.
# Ep 720; 77 steps. 100 ep ravg: 195.0. Eps 0.01. Loss: 0.00|0.39|3.39
# Target network updated.
# Ep 730; 29 steps. 100 ep ravg: 192.0. Eps 0.01. Loss: 0.00|0.32|3.42
# Target network updated.
# Target network updated.
# Ep 740; 200 steps. 100 ep ravg: 186.0. Eps 0.01. Loss: 0.00|0.28|3.88
# Target network updated.
# Target network updated.
# Ep 750; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.34|4.00
# Target network updated.
# Target network updated.
# Ep 760; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.43|3.90
# Target network updated.
# Target network updated.
# Ep 770; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.29|6.03
# Target network updated.
# Target network updated.
# Ep 780; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.33|4.10
# Target network updated.
# Target network updated.
# Ep 790; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.24|2.14
# Target network updated.
# Target network updated.
# Ep 800; 200 steps. 100 ep ravg: 184.0. Eps 0.01. Loss: 0.00|0.38|2.15
# Target network updated.
# Target network updated.
# Ep 810; 200 steps. 100 ep ravg: 186.0. Eps 0.01. Loss: 0.00|0.47|4.33
# Target network updated.
# Target network updated.
# Ep 820; 200 steps. 100 ep ravg: 188.0. Eps 0.01. Loss: 0.00|0.32|4.26
# Target network updated.
# Target network updated.
# Ep 830; 200 steps. 100 ep ravg: 191.0. Eps 0.01. Loss: 0.00|0.56|4.31
# Target network updated.
# Target network updated.
# Ep 840; 200 steps. 100 ep ravg: 197.0. Eps 0.01. Loss: 0.00|0.43|4.30
# Target network updated.
# Target network updated.
# Ep 850; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.40|2.25
# Target network updated.
# Target network updated.
# Ep 860; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.25|2.27
# Target network updated.
# Target network updated.
# Ep 870; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.36|4.54
# Target network updated.
# Target network updated.
# Ep 880; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.27|4.44
# Target network updated.
# Target network updated.
# Ep 890; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.33|4.64
# Target network updated.
# Target network updated.
# Ep 900; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.25|2.35
# Target network updated.
# Target network updated.
# Ep 910; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.49|4.67
# Target network updated.
# Target network updated.
# Ep 920; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.56|2.37
# Target network updated.
# Target network updated.
# Ep 930; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.52|4.74
# Target network updated.
# Target network updated.
# Ep 940; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.55|4.76
# Target network updated.
# Target network updated.
# Ep 950; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.50|4.84
# Target network updated.
# Target network updated.
# Ep 960; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.36|4.83
# Target network updated.
# Target network updated.
# Ep 970; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.24|2.45
# Target network updated.
# Target network updated.
# Ep 980; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.63|4.91
# Target network updated.
# Target network updated.
# Ep 990; 200 steps. 100 ep ravg: 199.0. Eps 0.01. Loss: 0.00|0.27|4.94
# Target network updated.
# Target network updated.

# %%
env = gym.make('CartPole-v0')
RANDOM_SEED = 2

torch.manual_seed(RANDOM_SEED)
env.seed(RANDOM_SEED)
env.action_space.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

dqn_agent = DQNAgent(learning_rate=0.00025, 
                     discount_rate=0.99,
                     num_inputs=4,
                     num_neurons=64,
                     num_outputs=2,
                     duelling=False,
                     loss_type='huber'
                    )

trainer = Trainer(
    env=env, 
    agent=dqn_agent, 
    memory_buffer=MemoryBuffer(buffer_length=50000), 
    start_epsilon=1, 
    timestep_to_start_learning=1000,
    batch_size=32,
    target_update_steps=1000,
    epsilon_decay_rate=0.99
)


trainer.run(num_episodes=1000)

results[RANDOM_SEED] = trainer.episode_lengths.copy()
# Out:
# Trainer initialised.
# Target network updated.
# Ep 0; 12 steps. 100 ep ravg: 11.0. Eps 1.00. Loss: inf|inf|inf
# Ep 10; 20 steps. 100 ep ravg: 23.0. Eps 0.90. Loss: inf|inf|inf
# Ep 20; 24 steps. 100 ep ravg: 23.0. Eps 0.82. Loss: inf|inf|inf
# Ep 30; 21 steps. 100 ep ravg: 21.0. Eps 0.74. Loss: inf|inf|inf
# Ep 40; 11 steps. 100 ep ravg: 19.0. Eps 0.67. Loss: inf|inf|inf
# Ep 50; 17 steps. 100 ep ravg: 18.0. Eps 0.61. Loss: inf|inf|inf
# Target network updated.
# Ep 60; 10 steps. 100 ep ravg: 17.0. Eps 0.55. Loss: 0.23|0.36|0.51
# Ep 70; 13 steps. 100 ep ravg: 17.0. Eps 0.49. Loss: 0.06|0.10|0.16
# Ep 80; 18 steps. 100 ep ravg: 16.0. Eps 0.45. Loss: 0.02|0.03|0.05
# Ep 90; 13 steps. 100 ep ravg: 16.0. Eps 0.40. Loss: 0.01|0.02|0.04
# Ep 100; 9 steps. 100 ep ravg: 15.0. Eps 0.37. Loss: 0.00|0.01|0.02
# Ep 110; 16 steps. 100 ep ravg: 14.0. Eps 0.33. Loss: 0.00|0.01|0.01
# Ep 120; 13 steps. 100 ep ravg: 13.0. Eps 0.30. Loss: 0.00|0.00|0.01
# Target network updated.
# Ep 130; 9 steps. 100 ep ravg: 12.0. Eps 0.27. Loss: 0.00|0.15|0.53
# Ep 140; 13 steps. 100 ep ravg: 12.0. Eps 0.24. Loss: 0.01|0.08|0.17
# Ep 150; 11 steps. 100 ep ravg: 11.0. Eps 0.22. Loss: 0.01|0.04|0.11
# Ep 160; 10 steps. 100 ep ravg: 11.0. Eps 0.20. Loss: 0.00|0.04|0.17
# Ep 170; 12 steps. 100 ep ravg: 11.0. Eps 0.18. Loss: 0.01|0.05|0.11
# Ep 180; 10 steps. 100 ep ravg: 10.0. Eps 0.16. Loss: 0.01|0.04|0.10
# Ep 190; 9 steps. 100 ep ravg: 10.0. Eps 0.15. Loss: 0.00|0.04|0.08
# Ep 200; 9 steps. 100 ep ravg: 9.0. Eps 0.13. Loss: 0.00|0.04|0.10
# Ep 210; 9 steps. 100 ep ravg: 9.0. Eps 0.12. Loss: 0.01|0.04|0.08
# Ep 220; 10 steps. 100 ep ravg: 9.0. Eps 0.11. Loss: 0.00|0.04|0.12
# Target network updated.
# Ep 230; 9 steps. 100 ep ravg: 9.0. Eps 0.10. Loss: 0.02|0.18|0.48
# Ep 240; 9 steps. 100 ep ravg: 9.0. Eps 0.09. Loss: 0.01|0.10|0.23
# Ep 250; 9 steps. 100 ep ravg: 9.0. Eps 0.08. Loss: 0.01|0.10|0.24
# Ep 260; 9 steps. 100 ep ravg: 9.0. Eps 0.07. Loss: 0.01|0.09|0.28
# Ep 270; 9 steps. 100 ep ravg: 8.0. Eps 0.07. Loss: 0.01|0.08|0.24
# Ep 280; 9 steps. 100 ep ravg: 8.0. Eps 0.06. Loss: 0.01|0.09|0.21
# Ep 290; 10 steps. 100 ep ravg: 8.0. Eps 0.05. Loss: 0.01|0.09|0.24
# Ep 300; 8 steps. 100 ep ravg: 8.0. Eps 0.05. Loss: 0.01|0.09|0.19
# Ep 310; 10 steps. 100 ep ravg: 8.0. Eps 0.04. Loss: 0.01|0.09|0.21
# Ep 320; 10 steps. 100 ep ravg: 8.0. Eps 0.04. Loss: 0.01|0.09|0.19
# Target network updated.
# Ep 330; 9 steps. 100 ep ravg: 8.0. Eps 0.04. Loss: 0.02|0.19|0.49
# Ep 340; 8 steps. 100 ep ravg: 8.0. Eps 0.03. Loss: 0.00|0.12|0.31
# Ep 350; 12 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.01|0.12|0.33
# Ep 360; 14 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.01|0.12|0.31
# Ep 370; 14 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.12|0.32
# Ep 380; 16 steps. 100 ep ravg: 10.0. Eps 0.02. Loss: 0.02|0.13|0.27
# Ep 390; 36 steps. 100 ep ravg: 11.0. Eps 0.02. Loss: 0.01|0.12|0.35
# Target network updated.
# Ep 400; 15 steps. 100 ep ravg: 11.0. Eps 0.02. Loss: 0.02|0.20|0.62
# Ep 410; 33 steps. 100 ep ravg: 13.0. Eps 0.02. Loss: 0.01|0.15|0.42
# Ep 420; 17 steps. 100 ep ravg: 14.0. Eps 0.01. Loss: 0.01|0.15|0.43
# Ep 430; 31 steps. 100 ep ravg: 15.0. Eps 0.01. Loss: 0.01|0.15|0.50
# Target network updated.
# Ep 440; 21 steps. 100 ep ravg: 17.0. Eps 0.01. Loss: 0.01|0.20|0.55
# Ep 450; 59 steps. 100 ep ravg: 20.0. Eps 0.01. Loss: 0.00|0.16|0.50
# Ep 460; 82 steps. 100 ep ravg: 24.0. Eps 0.01. Loss: 0.01|0.15|0.52
# Target network updated.
# Ep 470; 96 steps. 100 ep ravg: 28.0. Eps 0.01. Loss: 0.01|0.22|0.57
# Target network updated.
# Ep 480; 64 steps. 100 ep ravg: 32.0. Eps 0.01. Loss: 0.01|0.18|0.58
# Ep 490; 47 steps. 100 ep ravg: 35.0. Eps 0.01. Loss: 0.01|0.20|0.64
# Target network updated.
# Ep 500; 38 steps. 100 ep ravg: 38.0. Eps 0.01. Loss: 0.01|0.24|0.65
# Ep 510; 46 steps. 100 ep ravg: 43.0. Eps 0.01. Loss: 0.00|0.18|0.65
# Target network updated.
# Ep 520; 74 steps. 100 ep ravg: 48.0. Eps 0.01. Loss: 0.00|0.20|1.05
# Target network updated.
# Ep 530; 158 steps. 100 ep ravg: 56.0. Eps 0.01. Loss: 0.00|0.20|0.78
# Target network updated.
# Ep 540; 98 steps. 100 ep ravg: 65.0. Eps 0.01. Loss: 0.00|0.20|0.86
# Target network updated.
# Ep 550; 137 steps. 100 ep ravg: 73.0. Eps 0.01. Loss: 0.00|0.20|1.10
# Target network updated.
# Target network updated.
# Ep 560; 77 steps. 100 ep ravg: 81.0. Eps 0.01. Loss: 0.00|0.23|0.75
# Target network updated.
# Ep 570; 62 steps. 100 ep ravg: 84.0. Eps 0.01. Loss: 0.00|0.26|1.15
# Ep 580; 70 steps. 100 ep ravg: 86.0. Eps 0.01. Loss: 0.00|0.26|1.22
# Target network updated.
# Ep 590; 69 steps. 100 ep ravg: 88.0. Eps 0.01. Loss: 0.00|0.35|1.41
# Target network updated.
# Ep 600; 42 steps. 100 ep ravg: 91.0. Eps 0.01. Loss: 0.00|0.23|0.89
# Ep 610; 10 steps. 100 ep ravg: 88.0. Eps 0.01. Loss: 0.00|0.28|1.66
# Target network updated.
# Ep 620; 45 steps. 100 ep ravg: 85.0. Eps 0.01. Loss: 0.00|0.33|1.31
# Ep 630; 10 steps. 100 ep ravg: 78.0. Eps 0.01. Loss: 0.00|0.32|1.46
# Ep 640; 9 steps. 100 ep ravg: 67.0. Eps 0.01. Loss: 0.00|0.34|1.79
# Ep 650; 9 steps. 100 ep ravg: 56.0. Eps 0.01. Loss: 0.00|0.33|1.35
# Ep 660; 8 steps. 100 ep ravg: 44.0. Eps 0.01. Loss: 0.00|0.32|1.22
# Ep 670; 54 steps. 100 ep ravg: 38.0. Eps 0.01. Loss: 0.00|0.32|2.48
# Target network updated.
# Ep 680; 9 steps. 100 ep ravg: 31.0. Eps 0.01. Loss: 0.00|0.37|1.84
# Ep 690; 10 steps. 100 ep ravg: 25.0. Eps 0.01. Loss: 0.01|0.41|2.19
# Ep 700; 8 steps. 100 ep ravg: 18.0. Eps 0.01. Loss: 0.00|0.43|1.72
# Ep 710; 10 steps. 100 ep ravg: 14.0. Eps 0.01. Loss: 0.00|0.39|1.55
# Ep 720; 11 steps. 100 ep ravg: 11.0. Eps 0.01. Loss: 0.00|0.47|1.61
# Ep 730; 9 steps. 100 ep ravg: 9.0. Eps 0.01. Loss: 0.00|0.43|1.46
# Ep 740; 10 steps. 100 ep ravg: 9.0. Eps 0.01. Loss: 0.00|0.47|1.65
# Ep 750; 10 steps. 100 ep ravg: 9.0. Eps 0.01. Loss: 0.00|0.45|1.84
# Ep 760; 9 steps. 100 ep ravg: 9.0. Eps 0.01. Loss: 0.00|0.47|1.89
# Ep 770; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.43|1.88
# Ep 780; 11 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.55|2.17
# Target network updated.
# Ep 790; 11 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.56|2.12
# Ep 800; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.53|2.42
# Ep 810; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.56|2.60
# Ep 820; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.44|2.33
# Ep 830; 8 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.54|2.24
# Ep 840; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.58|2.25
# Ep 850; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.52|2.05
# Ep 860; 11 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.50|2.53
# Ep 870; 11 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.61|2.50
# Ep 880; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.52|2.15
# Target network updated.
# Ep 890; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.58|2.07
# Ep 900; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.01|0.72|4.03
# Ep 910; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.69|3.04
# Ep 920; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.61|2.33
# Ep 930; 8 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.62|1.95
# Ep 940; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.62|2.08
# Ep 950; 11 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.67|2.61
# Ep 960; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.69|2.84
# Ep 970; 10 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.61|1.86
# Ep 980; 11 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.65|2.24
# Ep 990; 9 steps. 100 ep ravg: 8.0. Eps 0.01. Loss: 0.00|0.65|2.35
# Target network updated.

# %%
env = gym.make('CartPole-v0')
RANDOM_SEED = 3

torch.manual_seed(RANDOM_SEED)
env.seed(RANDOM_SEED)
env.action_space.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

dqn_agent = DQNAgent(learning_rate=0.00025, 
                     discount_rate=0.99,
                     num_inputs=4,
                     num_neurons=64,
                     num_outputs=2,
                     duelling=False,
                     loss_type='huber'
                    )

trainer = Trainer(
    env=env, 
    agent=dqn_agent, 
    memory_buffer=MemoryBuffer(buffer_length=50000), 
    start_epsilon=1, 
    timestep_to_start_learning=1000,
    batch_size=32,
    target_update_steps=1000,
    epsilon_decay_rate=0.99
)


trainer.run(num_episodes=500)

results[RANDOM_SEED] = trainer.episode_lengths.copy()
# Out:
# Trainer initialised.
# Target network updated.
# Ep 0; 11 steps. 100 ep ravg: 10.0. Eps 1.00. Loss: inf|inf|inf
# Ep 10; 17 steps. 100 ep ravg: 13.0. Eps 0.90. Loss: inf|inf|inf
# Ep 20; 31 steps. 100 ep ravg: 20.0. Eps 0.82. Loss: inf|inf|inf
# Ep 30; 22 steps. 100 ep ravg: 19.0. Eps 0.74. Loss: inf|inf|inf
# Ep 40; 11 steps. 100 ep ravg: 18.0. Eps 0.67. Loss: inf|inf|inf
# Ep 50; 13 steps. 100 ep ravg: 17.0. Eps 0.61. Loss: inf|inf|inf
# Target network updated.
# Ep 60; 16 steps. 100 ep ravg: 16.0. Eps 0.55. Loss: 0.33|0.43|0.55
# Ep 70; 10 steps. 100 ep ravg: 16.0. Eps 0.49. Loss: 0.08|0.16|0.24
# Ep 80; 13 steps. 100 ep ravg: 15.0. Eps 0.45. Loss: 0.04|0.06|0.10
# Ep 90; 27 steps. 100 ep ravg: 15.0. Eps 0.40. Loss: 0.02|0.03|0.04
# Ep 100; 12 steps. 100 ep ravg: 15.0. Eps 0.37. Loss: 0.01|0.02|0.03
# Ep 110; 12 steps. 100 ep ravg: 14.0. Eps 0.33. Loss: 0.01|0.01|0.02
# Ep 120; 13 steps. 100 ep ravg: 13.0. Eps 0.30. Loss: 0.00|0.01|0.02
# Target network updated.
# Ep 130; 13 steps. 100 ep ravg: 12.0. Eps 0.27. Loss: 0.00|0.03|0.49
# Ep 140; 9 steps. 100 ep ravg: 12.0. Eps 0.24. Loss: 0.04|0.16|0.46
# Ep 150; 10 steps. 100 ep ravg: 11.0. Eps 0.22. Loss: 0.01|0.04|0.08
# Ep 160; 10 steps. 100 ep ravg: 11.0. Eps 0.20. Loss: 0.00|0.03|0.07
# Ep 170; 12 steps. 100 ep ravg: 10.0. Eps 0.18. Loss: 0.00|0.03|0.07
# Ep 180; 10 steps. 100 ep ravg: 10.0. Eps 0.16. Loss: 0.00|0.02|0.08
# Ep 190; 11 steps. 100 ep ravg: 10.0. Eps 0.15. Loss: 0.00|0.02|0.05
# Ep 200; 12 steps. 100 ep ravg: 10.0. Eps 0.13. Loss: 0.00|0.02|0.07
# Ep 210; 11 steps. 100 ep ravg: 9.0. Eps 0.12. Loss: 0.00|0.02|0.06
# Ep 220; 12 steps. 100 ep ravg: 9.0. Eps 0.11. Loss: 0.00|0.02|0.06
# Target network updated.
# Ep 230; 9 steps. 100 ep ravg: 9.0. Eps 0.10. Loss: 0.00|0.13|0.50
# Ep 240; 11 steps. 100 ep ravg: 9.0. Eps 0.09. Loss: 0.01|0.11|0.24
# Ep 250; 10 steps. 100 ep ravg: 9.0. Eps 0.08. Loss: 0.01|0.09|0.21
# Ep 260; 11 steps. 100 ep ravg: 9.0. Eps 0.07. Loss: 0.01|0.09|0.22
# Ep 270; 10 steps. 100 ep ravg: 9.0. Eps 0.07. Loss: 0.00|0.08|0.26
# Ep 280; 10 steps. 100 ep ravg: 9.0. Eps 0.06. Loss: 0.00|0.07|0.17
# Ep 290; 11 steps. 100 ep ravg: 9.0. Eps 0.05. Loss: 0.01|0.08|0.22
# Ep 300; 8 steps. 100 ep ravg: 9.0. Eps 0.05. Loss: 0.01|0.07|0.16
# Ep 310; 8 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.01|0.08|0.22
# Ep 320; 9 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.01|0.08|0.20
# Target network updated.
# Ep 330; 9 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.02|0.19|0.55
# Ep 340; 10 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.01|0.16|0.39
# Ep 350; 10 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.01|0.15|0.35
# Ep 360; 10 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.01|0.13|0.39
# Ep 370; 12 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.14|0.36
# Ep 380; 11 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.15|0.37
# Ep 390; 13 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.13|0.30
# Ep 400; 12 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.15|0.38
# Ep 410; 16 steps. 100 ep ravg: 10.0. Eps 0.02. Loss: 0.01|0.14|0.35
# Target network updated.
# Ep 420; 11 steps. 100 ep ravg: 10.0. Eps 0.01. Loss: 0.01|0.24|0.56
# Ep 430; 14 steps. 100 ep ravg: 10.0. Eps 0.01. Loss: 0.01|0.20|0.58
# Ep 440; 12 steps. 100 ep ravg: 11.0. Eps 0.01. Loss: 0.01|0.21|0.48
# Ep 450; 16 steps. 100 ep ravg: 11.0. Eps 0.01. Loss: 0.01|0.19|0.55
# Ep 460; 16 steps. 100 ep ravg: 12.0. Eps 0.01. Loss: 0.01|0.20|0.57
# Target network updated.
# Ep 470; 12 steps. 100 ep ravg: 14.0. Eps 0.01. Loss: 0.01|0.24|0.67
# Ep 480; 21 steps. 100 ep ravg: 14.0. Eps 0.01. Loss: 0.01|0.26|0.66
# Ep 490; 18 steps. 100 ep ravg: 15.0. Eps 0.01. Loss: 0.01|0.24|0.65

# %%
env = gym.make('CartPole-v0')
RANDOM_SEED = 4

torch.manual_seed(RANDOM_SEED)
env.seed(RANDOM_SEED)
env.action_space.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

dqn_agent = DQNAgent(learning_rate=0.00025, 
                     discount_rate=0.99,
                     num_inputs=4,
                     num_neurons=64,
                     num_outputs=2,
                     duelling=False,
                     loss_type='huber'
                    )

trainer = Trainer(
    env=env, 
    agent=dqn_agent, 
    memory_buffer=MemoryBuffer(buffer_length=50000), 
    start_epsilon=1, 
    timestep_to_start_learning=1000,
    batch_size=32,
    target_update_steps=1000,
    epsilon_decay_rate=0.99
)


trainer.run(num_episodes=1000)

results[RANDOM_SEED] = trainer.episode_lengths.copy()
# Out:
# Trainer initialised.
# Target network updated.
# Ep 0; 38 steps. 100 ep ravg: 37.0. Eps 1.00. Loss: inf|inf|inf
# Ep 10; 11 steps. 100 ep ravg: 22.0. Eps 0.90. Loss: inf|inf|inf
# Ep 20; 15 steps. 100 ep ravg: 18.0. Eps 0.82. Loss: inf|inf|inf
# Ep 30; 17 steps. 100 ep ravg: 17.0. Eps 0.74. Loss: inf|inf|inf
# Ep 40; 14 steps. 100 ep ravg: 17.0. Eps 0.67. Loss: inf|inf|inf
# Ep 50; 12 steps. 100 ep ravg: 17.0. Eps 0.61. Loss: inf|inf|inf
# Target network updated.
# Ep 60; 15 steps. 100 ep ravg: 16.0. Eps 0.55. Loss: 0.27|0.41|0.57
# Ep 70; 9 steps. 100 ep ravg: 15.0. Eps 0.49. Loss: 0.08|0.15|0.24
# Ep 80; 14 steps. 100 ep ravg: 15.0. Eps 0.45. Loss: 0.03|0.06|0.10
# Ep 90; 12 steps. 100 ep ravg: 15.0. Eps 0.40. Loss: 0.01|0.02|0.03
# Ep 100; 30 steps. 100 ep ravg: 16.0. Eps 0.37. Loss: 0.00|0.00|0.01
# Target network updated.
# Ep 110; 16 steps. 100 ep ravg: 17.0. Eps 0.33. Loss: 0.00|0.16|0.48
# Ep 120; 24 steps. 100 ep ravg: 18.0. Eps 0.30. Loss: 0.00|0.03|0.08
# Ep 130; 16 steps. 100 ep ravg: 18.0. Eps 0.27. Loss: 0.00|0.02|0.10
# Ep 140; 10 steps. 100 ep ravg: 17.0. Eps 0.24. Loss: 0.00|0.02|0.08
# Ep 150; 16 steps. 100 ep ravg: 17.0. Eps 0.22. Loss: 0.00|0.02|0.07
# Ep 160; 14 steps. 100 ep ravg: 16.0. Eps 0.20. Loss: 0.00|0.03|0.09
# Target network updated.
# Ep 170; 10 steps. 100 ep ravg: 17.0. Eps 0.18. Loss: 0.00|0.11|0.48
# Ep 180; 18 steps. 100 ep ravg: 17.0. Eps 0.16. Loss: 0.00|0.07|0.26
# Ep 190; 22 steps. 100 ep ravg: 18.0. Eps 0.15. Loss: 0.00|0.07|0.19
# Ep 200; 9 steps. 100 ep ravg: 18.0. Eps 0.13. Loss: 0.00|0.06|0.16
# Ep 210; 10 steps. 100 ep ravg: 16.0. Eps 0.12. Loss: 0.00|0.05|0.19
# Ep 220; 35 steps. 100 ep ravg: 15.0. Eps 0.11. Loss: 0.00|0.07|0.24
# Target network updated.
# Ep 230; 8 steps. 100 ep ravg: 14.0. Eps 0.10. Loss: 0.00|0.12|0.60
# Ep 240; 35 steps. 100 ep ravg: 14.0. Eps 0.09. Loss: 0.00|0.12|0.35
# Ep 250; 13 steps. 100 ep ravg: 14.0. Eps 0.08. Loss: 0.00|0.13|0.37
# Ep 260; 11 steps. 100 ep ravg: 14.0. Eps 0.07. Loss: 0.00|0.13|0.37
# Ep 270; 10 steps. 100 ep ravg: 13.0. Eps 0.07. Loss: 0.00|0.13|0.35
# Ep 280; 12 steps. 100 ep ravg: 12.0. Eps 0.06. Loss: 0.00|0.12|0.36
# Ep 290; 12 steps. 100 ep ravg: 11.0. Eps 0.05. Loss: 0.00|0.14|0.35
# Ep 300; 10 steps. 100 ep ravg: 10.0. Eps 0.05. Loss: 0.00|0.14|0.40
# Ep 310; 10 steps. 100 ep ravg: 10.0. Eps 0.04. Loss: 0.01|0.13|0.41
# Ep 320; 9 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.00|0.14|0.35
# Target network updated.
# Ep 330; 9 steps. 100 ep ravg: 9.0. Eps 0.04. Loss: 0.00|0.23|0.72
# Ep 340; 9 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.00|0.20|0.54
# Ep 350; 19 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.00|0.19|0.68
# Ep 360; 10 steps. 100 ep ravg: 9.0. Eps 0.03. Loss: 0.00|0.18|0.54
# Ep 370; 9 steps. 100 ep ravg: 10.0. Eps 0.02. Loss: 0.00|0.19|0.59
# Ep 380; 10 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.00|0.19|0.51
# Ep 390; 10 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.20|0.73
# Ep 400; 10 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.19|0.53
# Ep 410; 8 steps. 100 ep ravg: 9.0. Eps 0.02. Loss: 0.01|0.20|0.75
# Target network updated.
# Ep 420; 28 steps. 100 ep ravg: 10.0. Eps 0.01. Loss: 0.00|0.27|0.68
# Ep 430; 31 steps. 100 ep ravg: 14.0. Eps 0.01. Loss: 0.01|0.26|0.76
# Ep 440; 9 steps. 100 ep ravg: 15.0. Eps 0.01. Loss: 0.00|0.27|0.69
# Target network updated.
# Ep 450; 48 steps. 100 ep ravg: 18.0. Eps 0.01. Loss: 0.00|0.27|1.04
# Target network updated.
# Ep 460; 79 steps. 100 ep ravg: 27.0. Eps 0.01. Loss: 0.01|0.31|0.77
# Target network updated.
# Ep 470; 141 steps. 100 ep ravg: 38.0. Eps 0.01. Loss: 0.00|0.27|1.15
# Target network updated.
# Ep 480; 164 steps. 100 ep ravg: 51.0. Eps 0.01. Loss: 0.00|0.26|0.89
# Target network updated.
# Target network updated.
# Ep 490; 136 steps. 100 ep ravg: 63.0. Eps 0.01. Loss: 0.00|0.37|1.13
# Target network updated.
# Ep 500; 200 steps. 100 ep ravg: 75.0. Eps 0.01. Loss: 0.00|0.33|1.33
# Target network updated.
# Ep 510; 139 steps. 100 ep ravg: 85.0. Eps 0.01. Loss: 0.00|0.36|1.57
# Target network updated.
# Ep 520; 98 steps. 100 ep ravg: 93.0. Eps 0.01. Loss: 0.00|0.40|1.39
# Target network updated.
# Ep 530; 90 steps. 100 ep ravg: 98.0. Eps 0.01. Loss: 0.00|0.41|1.57
# Target network updated.
# Ep 540; 105 steps. 100 ep ravg: 105.0. Eps 0.01. Loss: 0.00|0.42|1.68
# Target network updated.
# Ep 550; 108 steps. 100 ep ravg: 110.0. Eps 0.01. Loss: 0.00|0.32|1.38
# Target network updated.
# Ep 560; 117 steps. 100 ep ravg: 110.0. Eps 0.01. Loss: 0.00|0.31|1.85
# Target network updated.
# Ep 570; 169 steps. 100 ep ravg: 109.0. Eps 0.01. Loss: 0.00|0.46|1.83
# Target network updated.
# Ep 580; 101 steps. 100 ep ravg: 106.0. Eps 0.01. Loss: 0.00|0.44|2.01
# Target network updated.
# Ep 590; 104 steps. 100 ep ravg: 103.0. Eps 0.01. Loss: 0.00|0.42|1.94
# Target network updated.
# Ep 600; 130 steps. 100 ep ravg: 100.0. Eps 0.01. Loss: 0.00|0.38|2.10
# Target network updated.
# Ep 610; 108 steps. 100 ep ravg: 102.0. Eps 0.01. Loss: 0.00|0.45|2.17
# Target network updated.
# Target network updated.
# Ep 620; 152 steps. 100 ep ravg: 105.0. Eps 0.01. Loss: 0.00|0.47|1.95
# Target network updated.
# Ep 630; 159 steps. 100 ep ravg: 111.0. Eps 0.01. Loss: 0.00|0.47|2.67
# Target network updated.
# Target network updated.
# Ep 640; 111 steps. 100 ep ravg: 116.0. Eps 0.01. Loss: 0.00|0.44|2.14
# Target network updated.
# Ep 650; 200 steps. 100 ep ravg: 120.0. Eps 0.01. Loss: 0.00|0.47|2.99
# Target network updated.
# Target network updated.
# Ep 660; 200 steps. 100 ep ravg: 124.0. Eps 0.01. Loss: 0.00|0.40|2.22
# Target network updated.
# Ep 670; 113 steps. 100 ep ravg: 128.0. Eps 0.01. Loss: 0.00|0.50|2.40
# Target network updated.
# Ep 680; 114 steps. 100 ep ravg: 131.0. Eps 0.01. Loss: 0.00|0.44|2.31
# Target network updated.
# Target network updated.
# Ep 690; 163 steps. 100 ep ravg: 138.0. Eps 0.01. Loss: 0.00|0.56|2.41
# Target network updated.
# Target network updated.
# Ep 700; 115 steps. 100 ep ravg: 143.0. Eps 0.01. Loss: 0.00|0.56|2.59
# Target network updated.
# Ep 710; 127 steps. 100 ep ravg: 145.0. Eps 0.01. Loss: 0.00|0.51|2.74
# Target network updated.
# Ep 720; 168 steps. 100 ep ravg: 145.0. Eps 0.01. Loss: 0.00|0.47|2.46
# Target network updated.
# Target network updated.
# Ep 730; 154 steps. 100 ep ravg: 147.0. Eps 0.01. Loss: 0.00|0.53|3.37
# Target network updated.
# Target network updated.
# Ep 740; 200 steps. 100 ep ravg: 150.0. Eps 0.01. Loss: 0.00|0.52|3.00
# Target network updated.
# Target network updated.
# Ep 750; 200 steps. 100 ep ravg: 153.0. Eps 0.01. Loss: 0.00|0.51|4.09
# Target network updated.
# Ep 760; 133 steps. 100 ep ravg: 153.0. Eps 0.01. Loss: 0.00|0.55|2.73
# Target network updated.
# Ep 770; 111 steps. 100 ep ravg: 153.0. Eps 0.01. Loss: 0.00|0.39|2.20
# Target network updated.
# Target network updated.
# Ep 780; 137 steps. 100 ep ravg: 155.0. Eps 0.01. Loss: 0.00|0.52|3.27
# Target network updated.
# Target network updated.
# Ep 790; 170 steps. 100 ep ravg: 154.0. Eps 0.01. Loss: 0.00|0.47|3.19
# Target network updated.
# Ep 800; 146 steps. 100 ep ravg: 152.0. Eps 0.01. Loss: 0.00|0.32|2.43
# Target network updated.
# Target network updated.
# Ep 810; 200 steps. 100 ep ravg: 153.0. Eps 0.01. Loss: 0.00|0.30|2.28
# Target network updated.
# Ep 820; 168 steps. 100 ep ravg: 157.0. Eps 0.01. Loss: 0.00|0.34|2.26
# Target network updated.
# Target network updated.
# Ep 830; 200 steps. 100 ep ravg: 158.0. Eps 0.01. Loss: 0.00|0.22|3.39
# Target network updated.
# Target network updated.
# Ep 840; 148 steps. 100 ep ravg: 158.0. Eps 0.01. Loss: 0.00|0.33|2.51
# Target network updated.
# Ep 850; 152 steps. 100 ep ravg: 155.0. Eps 0.01. Loss: 0.00|0.28|2.39
# Target network updated.
# Target network updated.
# Ep 860; 177 steps. 100 ep ravg: 159.0. Eps 0.01. Loss: 0.00|0.22|2.39
# Target network updated.
# Target network updated.
# Ep 870; 200 steps. 100 ep ravg: 161.0. Eps 0.01. Loss: 0.00|0.25|3.71
# Target network updated.
# Target network updated.
# Ep 880; 200 steps. 100 ep ravg: 163.0. Eps 0.01. Loss: 0.00|0.38|2.74
# Target network updated.
# Ep 890; 200 steps. 100 ep ravg: 167.0. Eps 0.01. Loss: 0.00|0.22|3.91
# Target network updated.
# Target network updated.
# Ep 900; 141 steps. 100 ep ravg: 168.0. Eps 0.01. Loss: 0.00|0.28|1.43
# Target network updated.
# Target network updated.
# Ep 910; 142 steps. 100 ep ravg: 170.0. Eps 0.01. Loss: 0.00|0.30|2.87
# Target network updated.
# Ep 920; 126 steps. 100 ep ravg: 170.0. Eps 0.01. Loss: 0.00|0.30|2.27
# Target network updated.
# Target network updated.
# Ep 930; 138 steps. 100 ep ravg: 164.0. Eps 0.01. Loss: 0.00|0.35|3.71
# Target network updated.
# Ep 940; 109 steps. 100 ep ravg: 162.0. Eps 0.01. Loss: 0.00|0.27|1.66
# Target network updated.
# Ep 950; 123 steps. 100 ep ravg: 158.0. Eps 0.01. Loss: 0.00|0.19|1.67
# Target network updated.
# Target network updated.
# Ep 960; 131 steps. 100 ep ravg: 154.0. Eps 0.01. Loss: 0.00|0.17|3.02
# Target network updated.
# Ep 970; 157 steps. 100 ep ravg: 154.0. Eps 0.01. Loss: 0.00|0.24|2.64
# Target network updated.
# Target network updated.
# Ep 980; 100 steps. 100 ep ravg: 148.0. Eps 0.01. Loss: 0.00|0.19|1.81
# Target network updated.
# Ep 990; 146 steps. 100 ep ravg: 141.0. Eps 0.01. Loss: 0.00|0.15|3.97
# Target network updated.

# %%
# %matplotlib inline
fig, ax = plt.subplots()
for seed, episode_lengths in results.items():
    plt.plot(episode_lengths,label=f'episode length ({seed})')
ax.set_xlabel('Episode')
ax.set_ylabel('Episode timesteps')
ax.set_title(f'Double DQN on CartPole: multiple random seeds')
ax.set_ylim(0, trainer.max_num_steps)
ax.set_xlim(0, len(trainer.episode_lengths))
# Out:
# (0, 1000)

# %%
# %matplotlib inline
fig, ax = plt.subplots()
for seed, episode_lengths in results.items():
    plt.plot(episode_lengths,label=f'episode length ({seed})')
ax.set_xlabel('Episode')
ax.set_ylabel('Episode timesteps')
ax.set_title(f'Double Duelling DQN on CartPole: multiple random seeds')
ax.set_ylim(0, trainer.max_num_steps)
ax.set_xlim(0, len(trainer.episode_lengths))
# Out:
# (0, 1000)

# %%
# %matplotlib inline
fig, ax = plt.subplots()
for seed, episode_lengths in results.items():
    plt.plot(episode_lengths,label=f'episode length ({seed})')
ax.set_xlabel('Episode')
ax.set_ylabel('Episode timesteps')
ax.set_title(f'Double DQN on CartPole, Huber loss: multiple random seeds')
ax.set_ylim(0, trainer.max_num_steps)
ax.set_xlim(0, len(trainer.episode_lengths))
# Out:
# (0, 1000)

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.plot(trainer.episode_lengths,label='episode length')
ax.set_xlabel('Episode')
ax.set_ylabel('Episode timesteps')
ax.set_title(f'Double DQN; batch size {trainer.batch_size}')
ax.set_ylim(0, trainer.max_num_steps)
ax.set_xlim(0, len(trainer.episode_lengths))
# Out:
# (0, 1000)
